# %% [markdown]
# ### Install the packages.

# %%
import pandas as pd

# %% [markdown]
# ### Data preparation

# %%
df = pd.read_csv('airbnb-listings.csv', error_bad_lines=False)

sample_df = df.sample(n=20)
sample_df.to_csv('sample_bnb.csv', index=False)
# Out:
# /Users/carolchen/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 7: expected 19 fields, saw 27\nSkipping line 8: expected 19 fields, saw 27\nSkipping line 14: expected 19 fields, saw 30\nSkipping line 15: expected 19 fields, saw 30\nSkipping line 16: expected 19 fields, saw 51\nSkipping line 17: expected 19 fields, saw 32\nSkipping line 18: expected 19 fields, saw 46\nSkipping line 19: expected 19 fields, saw 63\nSkipping line 20: expected 19 fields, saw 67\nSkipping line 21: expected 19 fields, saw 47\nSkipping line 22: expected 19 fields, saw 44\nSkipping line 23: expected 19 fields, saw 60\nSkipping line 24: expected 19 fields, saw 37\nSkipping line 28: expected 19 fields, saw 31\nSkipping line 29: expected 19 fields, saw 53\nSkipping line 30: expected 19 fields, saw 41\nSkipping line 32: expected 19 fields, saw 30\nSkipping line 33: expected 19 fields, saw 54\nSkipping line 34: expected 19 fields, saw 45\nSkipping line 35: expected 19 fields, saw 30\nSkipping line 36: expected 19 fields, saw 55\nSkipping line 40: expected 19 fields, saw 25\nSkipping line 41: expected 19 fields, saw 78\nSkipping line 42: expected 19 fields, saw 21\nSkipping line 45: expected 19 fields, saw 46\nSkipping line 46: expected 19 fields, saw 46\nSkipping line 48: expected 19 fields, saw 25\nSkipping line 49: expected 19 fields, saw 39\nSkipping line 50: expected 19 fields, saw 37\nSkipping line 52: expected 19 fields, saw 20\nSkipping line 53: expected 19 fields, saw 85\nSkipping line 54: expected 19 fields, saw 31\nSkipping line 55: expected 19 fields, saw 57\nSkipping line 56: expected 19 fields, saw 27\nSkipping line 57: expected 19 fields, saw 26\nSkipping line 63: expected 19 fields, saw 26\nSkipping line 64: expected 19 fields, saw 67\nSkipping line 66: expected 19 fields, saw 32\nSkipping line 67: expected 19 fields, saw 26\nSkipping line 68: expected 19 fields, saw 24\nSkipping line 69: expected 19 fields, saw 34\nSkipping line 70: expected 19 fields, saw 34\nSkipping line 77: expected 19 fields, saw 28\nSkipping line 78: expected 19 fields, saw 36\nSkipping line 79: expected 19 fields, saw 32\nSkipping line 85: expected 19 fields, saw 39\nSkipping line 86: expected 19 fields, saw 21\nSkipping line 87: expected 19 fields, saw 56\nSkipping line 88: expected 19 fields, saw 24\nSkipping line 89: expected 19 fields, saw 46\nSkipping line 90: expected 19 fields, saw 27\nSkipping line 91: expected 19 fields, saw 33\nSkipping line 92: expected 19 fields, saw 29\nSkipping line 94: expected 19 fields, saw 44\nSkipping line 95: expected 19 fields, saw 38\nSkipping line 97: expected 19 fields, saw 27\nSkipping line 98: expected 19 fields, saw 46\nSkipping line 99: expected 19 fields, saw 57\nSkipping line 100: expected 19 fields, saw 22\nSkipping line 101: expected 19 fields, saw 55\nSkipping line 102: expected 19 fields, saw 22\nSkipping line 103: expected 19 fields, saw 40\nSkipping line 104: expected 19 fields, saw 20\nSkipping line 107: expected 19 fields, saw 29\nSkipping line 108: expected 19 fields, saw 66\nSkipping line 109: expected 19 fields, saw 39\nSkipping line 110: expected 19 fields, saw 46\nSkipping line 111: expected 19 fields, saw 45\nSkipping line 112: expected 19 fields, saw 51\nSkipping line 120: expected 19 fields, saw 29\nSkipping line 121: expected 19 fields, saw 21\nSkipping line 126: expected 19 fields, saw 35\nSkipping line 127: expected 19 fields, saw 30\nSkipping line 128: expected 19 fields, saw 44\nSkipping line 133: expected 19 fields, saw 46\nSkipping line 134: expected 19 fields, saw 51\nSkipping line 140: expected 19 fields, saw 23\nSkipping line 141: expected 19 fields, saw 35\nSkipping line 142: expected 19 fields, saw 28\nSkipping line 143: expected 19 fields, saw 27\nSkipping line 144: expected 19 fields, saw 27\nSkipping line 147: expected 19 fields, saw 28\nSkipping line 148: expected 19 fields, saw 26\nSkipping line 149: expected 19 fields, saw 65\nSkipping line 150: expected 19 fields, saw 23\nSkipping line 151: expected 19 fields, saw 39\nSkipping line 15 ...
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/41/gvs7jv217519rgnddb2ng5m00000gn/T/ipykernel_5169/2684192552.py in <module>
# ----> 1 df = pd.read_csv('airbnb-listings.csv', error_bad_lines=False)
#       2
#       3 sample_df = df.sample(n=20)
#       4 sample_df.to_csv('sample_bnb.csv', index=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %% [markdown]
# ### Questions

# %% [markdown]
# 1. How many listings are in my neighbourhood and where are they?

# %% [markdown]
# 2. How many houses and apartments are being rented out frequently to tourists and not to long-term residents?

# %% [markdown]
# 3. How much are hosts making from renting to tourists (compare that to long-term rentals)

# %% [markdown]
# 4. Which hosts are running a business with multiple listings and where they?
